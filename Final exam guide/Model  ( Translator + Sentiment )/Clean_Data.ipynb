# %%
# import libraries

import requests
import pandas as pd

# %%
def query_translation(payload):
    response = requests.post(API_URL_translate, headers=headers, json=payload)
    return response.json()

def query_sentiment(payload):
    response = requests.post(API_URL_sentiment, headers=headers, json=payload)
    return response.json()

def fillna_mean(df):
    _numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    _cols = df.shape[1]
    for i in range(_cols):
        if df.iloc[:,i].dtypes in _numerics:
            df.iloc[:,i] = df.iloc[:,i].fillna(df.iloc[:,i].mean())
    return df

def addMean_column(df,iStart,iEnd):
    _numColumns = iEnd - iStart
    _series = df.iloc[:,iStart]
    if _numColumns == 1:
        df.loc[:,'Mean_Point'] = _series
        return df
    elif _numColumns < 1:
        return
    else:
        for i in range(iStart+1,iEnd):
            _series = _series + df.iloc[:,i]
        _series = _series / (_numColumns * 10)
        df.loc[:,'Mean_Point'] = _series
        return df

def translate_en_th(inputs_text):
    _translate_output = query_translation({ "inputs": inputs_text, })
    return _translate_output[0]['translation_text']

def sentiment_analysis(translated_text):
    _sentiment_output = query_sentiment({ "inputs": translated_text, })
    return _sentiment_output[0]

def positive_score(sentiment_set):
    if sentiment_set[0]['label'] == 'POSITIVE':
        return sentiment_set[0]['score']
    else:
        return sentiment_set[1]['score']

def negative_score(sentiment_set):
    if sentiment_set[0]['label'] == 'NEGATIVE':
        return sentiment_set[0]['score']
    else:
        return sentiment_set[1]['score']

# %%
# Connect to API

HuggingFace_Token = "Bearer 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"

API_URL_translate = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-th-en"
API_URL_sentiment = "https://api-inference.huggingface.co/models/distilbert/distilbert-base-uncased-finetuned-sst-2-english"

headers = {"Authorization": HuggingFace_Token}

# %%
# Read data

df = pd.read_excel("data.xlsx")
df
# Out:
#       ID          Start time     Completion time      Email  Name Language  \
# 0    240 2023-08-03 07:34:18 2023-08-03 07:36:30  anonymous   NaN      ไทย
# 1    241 2023-08-07 07:24:47 2023-08-07 07:25:36  anonymous   NaN      ไทย
# 2    242 2023-08-07 07:25:43 2023-08-07 07:26:25  anonymous   NaN      ไทย
# 3    243 2023-08-07 07:26:29 2023-08-07 07:27:23  anonymous   NaN      ไทย
# 4    244 2023-08-07 07:27:28 2023-08-07 07:28:16  anonymous   NaN      ไทย
# ..   ...                 ...                 ...        ...   ...      ...
# 349  589 2024-05-02 12:44:34 2024-05-02 12:47:02  anonymous   NaN      ไทย
# 350  590 2024-05-02 13:09:21 2024-05-02 13:11:20  anonymous   NaN      ไทย
# 351  591 2024-05-02 13:09:17 2024-05-02 13:11:42  anonymous   NaN      ไทย
# 352  592 2024-05-03 09:13:21 2024-05-03 09:22:26  anonymous   NaN      ไทย
# 353  593 2024-05-04 20:10:13 2024-05-04 20:10:53  anonymous   NaN      ไทย
#
#      อายุ     เพศ  MSQ_1  MSQ_2  ...  MSQ_4  MSQ_5  MSQ_6  MSQ_7  MSQ_8  \
# 0      47     ชาย   10.0   10.0  ...    8.0    8.0   10.0      8   10.0
# 1      25  LGBTQ+   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
# 2      30     ชาย   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
# 3      39     ชาย   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
# 4      29    หญิง   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
# ..    ...     ...    ...    ...  ...    ...    ...    ...    ...    ...
# 349    42     ชาย    NaN    9.0  ...    8.0    9.0   10.0      9    9.0
# 350    46     ชาย    8.0   10.0  ...    7.0    7.0    9.0      8    9.0
# 351    46     ชาย    NaN    8.0  ...    9.0    NaN    NaN      8   10.0
# 352    25     ชาย   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
# 353    29    หญิง   10.0   10.0  ...   10.0   10.0   10.0     10   10.0
#
#      MSQ_9  MSQ_10 MSQ_11  MSQ_12  \
# 0       10     ใช่    NaN  แน่นอน
# 1       10     ใช่    NaN  แน่นอน
# 2       10     ใช่    NaN   อาจจะ
# 3       10     ใช่    NaN  แน่นอน
# 4       10     ใช่    NaN  แน่นอน
# ..     ...     ...    ...     ...
# 349      9     ใช่    NaN  แน่นอน
# 350      8     ใช่    NaN  แน่นอน
# 351      8     ใช่    NaN  แน่นอน
# 352     10     ใช่    NaN  แน่นอน
# 353     10     ใช่    NaN  แน่นอน
#
#                                                 MSQ_13
# 0                                                  NaN
# 1        กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2                                      การบริการดีครับ
# 3                                                  NaN
# 4              เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
# ..                                                 ...
# 349                                          ไม่มีครับ
# 350                                                NaN
# 351                                                NaN
# 352  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...
# 353                                           บริการดี
#
# [354 rows x 21 columns]

# %%
df = fillna_mean(df)
df = addMean_column(df,8,17)
df = df.rename(columns={'Start time':'Date', 'อายุ':'Age', 'เพศ':'Gender', 'MSQ_13': 'Comment'})

# Define age ranges (modify these as needed)
bins = [0, 18, 25, 35, 45, 65, float('inf')]
labels = ['0-17', '18-24', '25-34', '35-44', '45-64', '65+']

# Create the new 'Age range' column using pandas.cut
df['Age_Range'] = pd.cut(df['Age'], bins=bins, labels=labels)
df
# Out:
#       ID                Date     Completion time      Email  Name Language  \
# 0    240 2023-08-03 07:34:18 2023-08-03 07:36:30  anonymous   NaN      ไทย
# 1    241 2023-08-07 07:24:47 2023-08-07 07:25:36  anonymous   NaN      ไทย
# 2    242 2023-08-07 07:25:43 2023-08-07 07:26:25  anonymous   NaN      ไทย
# 3    243 2023-08-07 07:26:29 2023-08-07 07:27:23  anonymous   NaN      ไทย
# 4    244 2023-08-07 07:27:28 2023-08-07 07:28:16  anonymous   NaN      ไทย
# ..   ...                 ...                 ...        ...   ...      ...
# 349  589 2024-05-02 12:44:34 2024-05-02 12:47:02  anonymous   NaN      ไทย
# 350  590 2024-05-02 13:09:21 2024-05-02 13:11:20  anonymous   NaN      ไทย
# 351  591 2024-05-02 13:09:17 2024-05-02 13:11:42  anonymous   NaN      ไทย
# 352  592 2024-05-03 09:13:21 2024-05-03 09:22:26  anonymous   NaN      ไทย
# 353  593 2024-05-04 20:10:13 2024-05-04 20:10:53  anonymous   NaN      ไทย
#
#      Age  Gender      MSQ_1  MSQ_2  ...      MSQ_6  MSQ_7  MSQ_8  MSQ_9  \
# 0     47     ชาย  10.000000   10.0  ...  10.000000      8   10.0     10
# 1     25  LGBTQ+  10.000000   10.0  ...  10.000000     10   10.0     10
# 2     30     ชาย  10.000000   10.0  ...  10.000000     10   10.0     10
# 3     39     ชาย  10.000000   10.0  ...  10.000000     10   10.0     10
# 4     29    หญิง  10.000000   10.0  ...  10.000000     10   10.0     10
# ..   ...     ...        ...    ...  ...        ...    ...    ...    ...
# 349   42     ชาย   9.581121    9.0  ...  10.000000      9    9.0      9
# 350   46     ชาย   8.000000   10.0  ...   9.000000      8    9.0      8
# 351   46     ชาย   9.581121    8.0  ...   9.479532      8   10.0      8
# 352   25     ชาย  10.000000   10.0  ...  10.000000     10   10.0     10
# 353   29    หญิง  10.000000   10.0  ...  10.000000     10   10.0     10
#
#      MSQ_10  MSQ_11  MSQ_12  \
# 0       ใช่     NaN  แน่นอน
# 1       ใช่     NaN  แน่นอน
# 2       ใช่     NaN   อาจจะ
# 3       ใช่     NaN  แน่นอน
# 4       ใช่     NaN  แน่นอน
# ..      ...     ...     ...
# 349     ใช่     NaN  แน่นอน
# 350     ใช่     NaN  แน่นอน
# 351     ใช่     NaN  แน่นอน
# 352     ใช่     NaN  แน่นอน
# 353     ใช่     NaN  แน่นอน
#
#                                                Comment Mean_Point Age_Range
# 0                                                  NaN   0.933333     45-64
# 1        กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก    1.000000     18-24
# 2                                      การบริการดีครับ   1.000000     25-34
# 3                                                  NaN   1.000000     35-44
# 4              เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี   1.000000     25-34
# ..                                                 ...        ...       ...
# 349                                          ไม่มีครับ   0.917568     35-44
# 350                                                NaN   0.833333     45-64
# 351                                                NaN   0.894414     45-64
# 352  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...   1.000000     18-24
# 353                                           บริการดี   1.000000     25-34
#
# [354 rows x 23 columns]

# %%
filtered_df = df[['ID','Comment']].copy()
filtered_df = filtered_df.dropna(subset=['Comment'])
filtered_df
# Out:
#       ID                                            Comment
# 1    241      กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2    242                                    การบริการดีครับ
# 4    244            เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
# 5    245  ภายในห้องพักมีกลิ่นหอมสะอาด พนักงานต้อนรับอย่า...
# 6    246  การต้อนรับอย่างดี Welcome drink ให้เเบบเย็นชื่...
# 15   255                         กลิ่นบนทางเดินเหม็นอับค่ะ
# 21   261    พนักงานให้คำเเนะนำได้ดี เตียงนุ่ม ห้องพักกว้าง
# 26   266                                 ห้องพักกว้างสะอาด
# 28   268  ควรจัดเตรียมของใช้ในห้อง เช่น รองเท้าสลิปเปอร์...
# 31   271                     น้องแนนหน้าฟ้อนบริการดีมากๆค่ะ
# 62   302                                               Good
# 63   303  บริการดี ยิ้มเเย้มเเจ่มใส กลับมาใช้บริการอีก เ...
# 67   307                                     รวมๆเเล้วโอเค
# 77   317                                      ห้องพักสะอาด
# 78   318  พนักงานบริการดีครับ ห้องพักกว้าง เเต่เเอบเสียด...
# 82   322                          ห้องพักกว้าง บริการดีครับ
# 83   323                     โรงเเรมติดถนนเดินทางสะดวกครับ
# 85   325  早上5:00，接待員服務很好，我告訴工作人員我沒有泰銖。然後工作人員帶我去ATM，謝謝。(A...
# 88   328  เข้ามาพักในนาม เเม็กโคร พนักงานบริการเป็นอย่าง...
# 90   330  มาจัดสัมมนาเเละพักที่นี้ ทางพนักงานต้อนรับเป็น...
# 92   332  พี่ๆพนักงานเคาน์เตอร์บริการดีมากๆ สอบถามข้อมูล...
# 95   335                                           ไม่มีค่ะ
# 96   336                                                405
# 97   337  ห้องพักสะอาดค่ะน้องๆบริหารดี แต่ตอนทานอาหารเช้...
# 102  342  ยังไม่เคยใช้บริการในส่วนของห้องสัมมนา เเต่ให้1...
# 135  375                   โรงแรม สวย สะอาด หอมมากภานในห้อง
# 137  377                                             ดีครับ
# 144  384                                ห้องพักสะอาดมากครับ
# 156  396  ห้องพักแอร์เสีย มีพัดลมเเอร์มาเเต่ไม่ช่วยห้องร...
# 160  400                                ห้องพักกว้างมากครับ
# 162  402                                              ดีค่ะ
# 166  406  ใกล้นิคมดีครับไปทำงานง่าย แต่ห้องยังไม่ค่อยเก็...
# 174  414                                  เดินทางสะดวกครับ
# 176  416  พนักงานบริการดี ห้องพักสะอาด แม่บ้านนน่ารักมาก...
# 179  419                                     อาหารอร่อยครับ
# 186  426    ไฟดับในห้องพักครับแต่ยังดีพนักงานเปลี่ยนห้องให้
# 193  433                                         ห้องสวยค่ะ
# 199  439                                     อาหารอร่อยค่ะ
# 204  444                                      ห้องสะอาดครับ
# 212  452  ห้องใหญ่มากค่ะบริการดีเสียดายจองผ่านแอพมาน่าจะ...
# 214  454                                      ผ้าเช็ดตัวขาด
# 222  462                                              ไม่มี
# 225  465  อยากให้ปรับปรุงมากๆ ด้วยราคานี้ค่อนข้างน่าผิดหวัง
# 228  468                                   ห้องกว้างเริ่ดดด
# 229  469                         อาหารอร่อย พนักงานบริการดี
# 230  470                           พี่พนักงานดูแลดีมากๆค่ะ
# 237  477                                           โอเคแล้ว
# 240  480                      ควรแจ้งการเปลี่ยนให้ดีกว่านี้
# 255  495                                      อาหารอร่อยค่ะ
# 258  498                                        บริการดีค่ะ
# 298  538                   อาหารอร่อย บรรยากาศในห้องอาหารดี
# 301  541              ห้องพักติดถนน เสียงดังไป เเต่โดยรวมดี
# 307  547                                           บริการดี
# 313  553                                            房间相当潮湿。
# 321  561                   ห้องค่อนข้างเสียงดังนิดหน่อยครับ
# 325  565                          อาหารอร่อย การบริการดีค่ะ
# 349  589                                          ไม่มีครับ
# 352  592  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...
# 353  593                                           บริการดี

# %%
filtered_df['translated'] = filtered_df.loc[:,'Comment'].apply(translate_en_th)
filtered_df
# Out:
#       ID                                            Comment  \
# 1    241      กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2    242                                    การบริการดีครับ
# 4    244            เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
# 5    245  ภายในห้องพักมีกลิ่นหอมสะอาด พนักงานต้อนรับอย่า...
# 6    246  การต้อนรับอย่างดี Welcome drink ให้เเบบเย็นชื่...
# 15   255                         กลิ่นบนทางเดินเหม็นอับค่ะ
# 21   261    พนักงานให้คำเเนะนำได้ดี เตียงนุ่ม ห้องพักกว้าง
# 26   266                                 ห้องพักกว้างสะอาด
# 28   268  ควรจัดเตรียมของใช้ในห้อง เช่น รองเท้าสลิปเปอร์...
# 31   271                     น้องแนนหน้าฟ้อนบริการดีมากๆค่ะ
# 62   302                                               Good
# 63   303  บริการดี ยิ้มเเย้มเเจ่มใส กลับมาใช้บริการอีก เ...
# 67   307                                     รวมๆเเล้วโอเค
# 77   317                                      ห้องพักสะอาด
# 78   318  พนักงานบริการดีครับ ห้องพักกว้าง เเต่เเอบเสียด...
# 82   322                          ห้องพักกว้าง บริการดีครับ
# 83   323                     โรงเเรมติดถนนเดินทางสะดวกครับ
# 85   325  早上5:00，接待員服務很好，我告訴工作人員我沒有泰銖。然後工作人員帶我去ATM，謝謝。(A...
# 88   328  เข้ามาพักในนาม เเม็กโคร พนักงานบริการเป็นอย่าง...
# 90   330  มาจัดสัมมนาเเละพักที่นี้ ทางพนักงานต้อนรับเป็น...
# 92   332  พี่ๆพนักงานเคาน์เตอร์บริการดีมากๆ สอบถามข้อมูล...
# 95   335                                           ไม่มีค่ะ
# 96   336                                                405
# 97   337  ห้องพักสะอาดค่ะน้องๆบริหารดี แต่ตอนทานอาหารเช้...
# 102  342  ยังไม่เคยใช้บริการในส่วนของห้องสัมมนา เเต่ให้1...
# 135  375                   โรงแรม สวย สะอาด หอมมากภานในห้อง
# 137  377                                             ดีครับ
# 144  384                                ห้องพักสะอาดมากครับ
# 156  396  ห้องพักแอร์เสีย มีพัดลมเเอร์มาเเต่ไม่ช่วยห้องร...
# 160  400                                ห้องพักกว้างมากครับ
# 162  402                                              ดีค่ะ
# 166  406  ใกล้นิคมดีครับไปทำงานง่าย แต่ห้องยังไม่ค่อยเก็...
# 174  414                                  เดินทางสะดวกครับ
# 176  416  พนักงานบริการดี ห้องพักสะอาด แม่บ้านนน่ารักมาก...
# 179  419                                     อาหารอร่อยครับ
# 186  426    ไฟดับในห้องพักครับแต่ยังดีพนักงานเปลี่ยนห้องให้
# 193  433                                         ห้องสวยค่ะ
# 199  439                                     อาหารอร่อยค่ะ
# 204  444                                      ห้องสะอาดครับ
# 212  452  ห้องใหญ่มากค่ะบริการดีเสียดายจองผ่านแอพมาน่าจะ...
# 214  454                                      ผ้าเช็ดตัวขาด
# 222  462                                              ไม่มี
# 225  465  อยากให้ปรับปรุงมากๆ ด้วยราคานี้ค่อนข้างน่าผิดหวัง
# 228  468                                   ห้องกว้างเริ่ดดด
# 229  469                         อาหารอร่อย พนักงานบริการดี
# 230  470                           พี่พนักงานดูแลดีมากๆค่ะ
# 237  477                                           โอเคแล้ว
# 240  480                      ควรแจ้งการเปลี่ยนให้ดีกว่านี้
# 255  495                                      อาหารอร่อยค่ะ
# 258  498                                        บริการดีค่ะ
# 298  538                   อาหารอร่อย บรรยากาศในห้องอาหารดี
# 301  541              ห้องพักติดถนน เสียงดังไป เเต่โดยรวมดี
# 307  547                                           บริการดี
# 313  553                                            房间相当潮湿。
# 321  561                   ห้องค่อนข้างเสียงดังนิดหน่อยครับ
# 325  565                          อาหารอร่อย การบริการดีค่ะ
# 349  589                                          ไม่มีครับ
# 352  592  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...
# 353  593                                           บริการดี
#
#                                             translated
# 1    We're back here on the fourth stop, sir. The r...
# 2                                        Good service.
# 4                Good journey, big road, good service.
# 5             There's a nice, clean smell in the room.
# 6                  Nice reception. Welcome drink cold.
# 15                    It's a bad smell in the hallway.
# 21   The employees gave good advice, the soft beds,...
# 26                                  The room is clean.
# 28   They should provide room-slipper shoes, room-t...
# 31                You're doing a really good job, Nan.
# 62                                               Good.
# 63   Good service, big smile, back to service, of c...
# 67                               It's okay. It's okay.
# 77                                       Room's clean.
# 78   Good staff, the room's wide, but unfortunately...
# 82                      It's a big room. Good service.
# 83                      The hotel's clear on the road.
# 85   (At 5pm, 8300 in the morning, the resort was g...
# 88   It's called Macro, a very good employee, a lar...
# 90   I'm here at the conference and I'm here at the...
# 92   The counter managers are very good, and they'r...
# 95                                            Nothing.
# 96                                                405.
# 97   The rooms are clean, my brothers and sisters a...
# 102  I haven't had a service in the conference room...
# 135     A nice, clean hotel. Smells great in the room.
# 137                                              Good.
# 144                            The room is very clean.
# 156  The E.R. Room's down. There's a power wave, bu...
# 160                        The room is very wide, sir.
# 162                                              Good.
# 166  It's very close to the colony, and it's easy t...
# 174                                 You're free to go.
# 176  Good stewards, clean rooms, nice maids, left s...
# 179                                         Good food.
# 186  The lights went out in the room, but the staff...
# 193                                         Nice room.
# 199                                    It's delicious.
# 204                                      Room's clean.
# 212  It's a big room. It's a nice service. I could ...
# 214                                The towel's broken.
# 222                                           Nothing.
# 225  I'd like to make a lot of improvements at this...
# 228                                   It's a big room.
# 229                             Good food, good staff.
# 230                       The staff's doing very well.
# 237                                        Okay, then.
# 240                A better change should be reported.
# 255                                    It's delicious.
# 258                                      Good service.
# 298  The food is good. The atmosphere is good in th...
# 301         Roadrooms are too loud, but it's all good.
# 307                                      Good service.
# 313                                          . . . . .
# 321                         The room's a little noisy.
# 325                           Good food. Good service.
# 349                                           No, sir.
# 352     The room is very nice. It's clean. Good staff.
# 353                                      Good service.

# %%
filtered_df['sentiment_set'] = filtered_df.loc[:,'translated'].apply(sentiment_analysis)
filtered_df
# Out:
#       ID                                            Comment  \
# 1    241      กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2    242                                    การบริการดีครับ
# 4    244            เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
# 5    245  ภายในห้องพักมีกลิ่นหอมสะอาด พนักงานต้อนรับอย่า...
# 6    246  การต้อนรับอย่างดี Welcome drink ให้เเบบเย็นชื่...
# 15   255                         กลิ่นบนทางเดินเหม็นอับค่ะ
# 21   261    พนักงานให้คำเเนะนำได้ดี เตียงนุ่ม ห้องพักกว้าง
# 26   266                                 ห้องพักกว้างสะอาด
# 28   268  ควรจัดเตรียมของใช้ในห้อง เช่น รองเท้าสลิปเปอร์...
# 31   271                     น้องแนนหน้าฟ้อนบริการดีมากๆค่ะ
# 62   302                                               Good
# 63   303  บริการดี ยิ้มเเย้มเเจ่มใส กลับมาใช้บริการอีก เ...
# 67   307                                     รวมๆเเล้วโอเค
# 77   317                                      ห้องพักสะอาด
# 78   318  พนักงานบริการดีครับ ห้องพักกว้าง เเต่เเอบเสียด...
# 82   322                          ห้องพักกว้าง บริการดีครับ
# 83   323                     โรงเเรมติดถนนเดินทางสะดวกครับ
# 85   325  早上5:00，接待員服務很好，我告訴工作人員我沒有泰銖。然後工作人員帶我去ATM，謝謝。(A...
# 88   328  เข้ามาพักในนาม เเม็กโคร พนักงานบริการเป็นอย่าง...
# 90   330  มาจัดสัมมนาเเละพักที่นี้ ทางพนักงานต้อนรับเป็น...
# 92   332  พี่ๆพนักงานเคาน์เตอร์บริการดีมากๆ สอบถามข้อมูล...
# 95   335                                           ไม่มีค่ะ
# 96   336                                                405
# 97   337  ห้องพักสะอาดค่ะน้องๆบริหารดี แต่ตอนทานอาหารเช้...
# 102  342  ยังไม่เคยใช้บริการในส่วนของห้องสัมมนา เเต่ให้1...
# 135  375                   โรงแรม สวย สะอาด หอมมากภานในห้อง
# 137  377                                             ดีครับ
# 144  384                                ห้องพักสะอาดมากครับ
# 156  396  ห้องพักแอร์เสีย มีพัดลมเเอร์มาเเต่ไม่ช่วยห้องร...
# 160  400                                ห้องพักกว้างมากครับ
# 162  402                                              ดีค่ะ
# 166  406  ใกล้นิคมดีครับไปทำงานง่าย แต่ห้องยังไม่ค่อยเก็...
# 174  414                                  เดินทางสะดวกครับ
# 176  416  พนักงานบริการดี ห้องพักสะอาด แม่บ้านนน่ารักมาก...
# 179  419                                     อาหารอร่อยครับ
# 186  426    ไฟดับในห้องพักครับแต่ยังดีพนักงานเปลี่ยนห้องให้
# 193  433                                         ห้องสวยค่ะ
# 199  439                                     อาหารอร่อยค่ะ
# 204  444                                      ห้องสะอาดครับ
# 212  452  ห้องใหญ่มากค่ะบริการดีเสียดายจองผ่านแอพมาน่าจะ...
# 214  454                                      ผ้าเช็ดตัวขาด
# 222  462                                              ไม่มี
# 225  465  อยากให้ปรับปรุงมากๆ ด้วยราคานี้ค่อนข้างน่าผิดหวัง
# 228  468                                   ห้องกว้างเริ่ดดด
# 229  469                         อาหารอร่อย พนักงานบริการดี
# 230  470                           พี่พนักงานดูแลดีมากๆค่ะ
# 237  477                                           โอเคแล้ว
# 240  480                      ควรแจ้งการเปลี่ยนให้ดีกว่านี้
# 255  495                                      อาหารอร่อยค่ะ
# 258  498                                        บริการดีค่ะ
# 298  538                   อาหารอร่อย บรรยากาศในห้องอาหารดี
# 301  541              ห้องพักติดถนน เสียงดังไป เเต่โดยรวมดี
# 307  547                                           บริการดี
# 313  553                                            房间相当潮湿。
# 321  561                   ห้องค่อนข้างเสียงดังนิดหน่อยครับ
# 325  565                          อาหารอร่อย การบริการดีค่ะ
# 349  589                                          ไม่มีครับ
# 352  592  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...
# 353  593                                           บริการดี
#
#                                             translated  \
# 1    We're back here on the fourth stop, sir. The r...
# 2                                        Good service.
# 4                Good journey, big road, good service.
# 5             There's a nice, clean smell in the room.
# 6                  Nice reception. Welcome drink cold.
# 15                    It's a bad smell in the hallway.
# 21   The employees gave good advice, the soft beds,...
# 26                                  The room is clean.
# 28   They should provide room-slipper shoes, room-t...
# 31                You're doing a really good job, Nan.
# 62                                               Good.
# 63   Good service, big smile, back to service, of c...
# 67                               It's okay. It's okay.
# 77                                       Room's clean.
# 78   Good staff, the room's wide, but unfortunately...
# 82                      It's a big room. Good service.
# 83                      The hotel's clear on the road.
# 85   (At 5pm, 8300 in the morning, the resort was g...
# 88   It's called Macro, a very good employee, a lar...
# 90   I'm here at the conference and I'm here at the...
# 92   The counter managers are very good, and they'r...
# 95                                            Nothing.
# 96                                                405.
# 97   The rooms are clean, my brothers and sisters a...
# 102  I haven't had a service in the conference room...
# 135     A nice, clean hotel. Smells great in the room.
# 137                                              Good.
# 144                            The room is very clean.
# 156  The E.R. Room's down. There's a power wave, bu...
# 160                        The room is very wide, sir.
# 162                                              Good.
# 166  It's very close to the colony, and it's easy t...
# 174                                 You're free to go.
# 176  Good stewards, clean rooms, nice maids, left s...
# 179                                         Good food.
# 186  The lights went out in the room, but the staff...
# 193                                         Nice room.
# 199                                    It's delicious.
# 204                                      Room's clean.
# 212  It's a big room. It's a nice service. I could ...
# 214                                The towel's broken.
# 222                                           Nothing.
# 225  I'd like to make a lot of improvements at this...
# 228                                   It's a big room.
# 229                             Good food, good staff.
# 230                       The staff's doing very well.
# 237                                        Okay, then.
# 240                A better change should be reported.
# 255                                    It's delicious.
# 258                                      Good service.
# 298  The food is good. The atmosphere is good in th...
# 301         Roadrooms are too loud, but it's all good.
# 307                                      Good service.
# 313                                          . . . . .
# 321                         The room's a little noisy.
# 325                           Good food. Good service.
# 349                                           No, sir.
# 352     The room is very nice. It's clean. Good staff.
# 353                                      Good service.
#
#                                          sentiment_set
# 1    [{'label': 'POSITIVE', 'score': 0.999060213565...
# 2    [{'label': 'POSITIVE', 'score': 0.999853372573...
# 4    [{'label': 'POSITIVE', 'score': 0.999871969223...
# 5    [{'label': 'POSITIVE', 'score': 0.999780356884...
# 6    [{'label': 'POSITIVE', 'score': 0.999289512634...
# 15   [{'label': 'NEGATIVE', 'score': 0.999786913394...
# 21   [{'label': 'POSITIVE', 'score': 0.997725903987...
# 26   [{'label': 'POSITIVE', 'score': 0.999398589134...
# 28   [{'label': 'NEGATIVE', 'score': 0.995548367500...
# 31   [{'label': 'POSITIVE', 'score': 0.999854445457...
# 62   [{'label': 'POSITIVE', 'score': 0.999815762042...
# 63   [{'label': 'POSITIVE', 'score': 0.999829411506...
# 67   [{'label': 'POSITIVE', 'score': 0.999826848506...
# 77   [{'label': 'POSITIVE', 'score': 0.999276340007...
# 78   [{'label': 'POSITIVE', 'score': 0.999377429485...
# 82   [{'label': 'POSITIVE', 'score': 0.999843835830...
# 83   [{'label': 'POSITIVE', 'score': 0.999705970287...
# 85   [{'label': 'POSITIVE', 'score': 0.970934271812...
# 88   [{'label': 'POSITIVE', 'score': 0.999601900577...
# 90   [{'label': 'POSITIVE', 'score': 0.998492598533...
# 92   [{'label': 'POSITIVE', 'score': 0.999853491783...
# 95   [{'label': 'NEGATIVE', 'score': 0.999634861946...
# 96   [{'label': 'NEGATIVE', 'score': 0.913557052612...
# 97   [{'label': 'NEGATIVE', 'score': 0.977753758430...
# 102  [{'label': 'POSITIVE', 'score': 0.999591886997...
# 135  [{'label': 'POSITIVE', 'score': 0.999877572059...
# 137  [{'label': 'POSITIVE', 'score': 0.999815762042...
# 144  [{'label': 'POSITIVE', 'score': 0.999219536781...
# 156  [{'label': 'NEGATIVE', 'score': 0.996005594730...
# 160  [{'label': 'POSITIVE', 'score': 0.999501347541...
# 162  [{'label': 'POSITIVE', 'score': 0.999815762042...
# 166  [{'label': 'NEGATIVE', 'score': 0.998827278614...
# 174  [{'label': 'POSITIVE', 'score': 0.999678850173...
# 176  [{'label': 'NEGATIVE', 'score': 0.980466306209...
# 179  [{'label': 'POSITIVE', 'score': 0.999863982200...
# 186  [{'label': 'NEGATIVE', 'score': 0.994319558143...
# 193  [{'label': 'POSITIVE', 'score': 0.999868035316...
# 199  [{'label': 'POSITIVE', 'score': 0.999880790710...
# 204  [{'label': 'POSITIVE', 'score': 0.999276340007...
# 212  [{'label': 'POSITIVE', 'score': 0.999519109725...
# 214  [{'label': 'NEGATIVE', 'score': 0.999607741832...
# 222  [{'label': 'NEGATIVE', 'score': 0.999634861946...
# 225  [{'label': 'NEGATIVE', 'score': 0.999548614025...
# 228  [{'label': 'POSITIVE', 'score': 0.999630451202...
# 229  [{'label': 'POSITIVE', 'score': 0.999863028526...
# 230  [{'label': 'POSITIVE', 'score': 0.999853372573...
# 237  [{'label': 'POSITIVE', 'score': 0.998957991600...
# 240  [{'label': 'NEGATIVE', 'score': 0.944746792316...
# 255  [{'label': 'POSITIVE', 'score': 0.999880790710...
# 258  [{'label': 'POSITIVE', 'score': 0.999853372573...
# 298  [{'label': 'POSITIVE', 'score': 0.999868392944...
# 301  [{'label': 'POSITIVE', 'score': 0.999775230884...
# 307  [{'label': 'POSITIVE', 'score': 0.999853372573...
# 313  [{'label': 'POSITIVE', 'score': 0.878417134284...
# 321  [{'label': 'NEGATIVE', 'score': 0.999675750732...
# 325  [{'label': 'POSITIVE', 'score': 0.999864935874...
# 349  [{'label': 'NEGATIVE', 'score': 0.999142646789...
# 352  [{'label': 'POSITIVE', 'score': 0.999870300292...
# 353  [{'label': 'POSITIVE', 'score': 0.999853372573...

# %%
filtered_df['Positive_Score'] = filtered_df.loc[:,'sentiment_set'].apply(positive_score)
filtered_df['Negative_Score'] = filtered_df.loc[:,'sentiment_set'].apply(negative_score)
filtered_df
# Out:
#       ID                                            Comment  \
# 1    241      กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2    242                                    การบริการดีครับ
# 4    244            เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
# 5    245  ภายในห้องพักมีกลิ่นหอมสะอาด พนักงานต้อนรับอย่า...
# 6    246  การต้อนรับอย่างดี Welcome drink ให้เเบบเย็นชื่...
# 15   255                         กลิ่นบนทางเดินเหม็นอับค่ะ
# 21   261    พนักงานให้คำเเนะนำได้ดี เตียงนุ่ม ห้องพักกว้าง
# 26   266                                 ห้องพักกว้างสะอาด
# 28   268  ควรจัดเตรียมของใช้ในห้อง เช่น รองเท้าสลิปเปอร์...
# 31   271                     น้องแนนหน้าฟ้อนบริการดีมากๆค่ะ
# 62   302                                               Good
# 63   303  บริการดี ยิ้มเเย้มเเจ่มใส กลับมาใช้บริการอีก เ...
# 67   307                                     รวมๆเเล้วโอเค
# 77   317                                      ห้องพักสะอาด
# 78   318  พนักงานบริการดีครับ ห้องพักกว้าง เเต่เเอบเสียด...
# 82   322                          ห้องพักกว้าง บริการดีครับ
# 83   323                     โรงเเรมติดถนนเดินทางสะดวกครับ
# 85   325  早上5:00，接待員服務很好，我告訴工作人員我沒有泰銖。然後工作人員帶我去ATM，謝謝。(A...
# 88   328  เข้ามาพักในนาม เเม็กโคร พนักงานบริการเป็นอย่าง...
# 90   330  มาจัดสัมมนาเเละพักที่นี้ ทางพนักงานต้อนรับเป็น...
# 92   332  พี่ๆพนักงานเคาน์เตอร์บริการดีมากๆ สอบถามข้อมูล...
# 95   335                                           ไม่มีค่ะ
# 96   336                                                405
# 97   337  ห้องพักสะอาดค่ะน้องๆบริหารดี แต่ตอนทานอาหารเช้...
# 102  342  ยังไม่เคยใช้บริการในส่วนของห้องสัมมนา เเต่ให้1...
# 135  375                   โรงแรม สวย สะอาด หอมมากภานในห้อง
# 137  377                                             ดีครับ
# 144  384                                ห้องพักสะอาดมากครับ
# 156  396  ห้องพักแอร์เสีย มีพัดลมเเอร์มาเเต่ไม่ช่วยห้องร...
# 160  400                                ห้องพักกว้างมากครับ
# 162  402                                              ดีค่ะ
# 166  406  ใกล้นิคมดีครับไปทำงานง่าย แต่ห้องยังไม่ค่อยเก็...
# 174  414                                  เดินทางสะดวกครับ
# 176  416  พนักงานบริการดี ห้องพักสะอาด แม่บ้านนน่ารักมาก...
# 179  419                                     อาหารอร่อยครับ
# 186  426    ไฟดับในห้องพักครับแต่ยังดีพนักงานเปลี่ยนห้องให้
# 193  433                                         ห้องสวยค่ะ
# 199  439                                     อาหารอร่อยค่ะ
# 204  444                                      ห้องสะอาดครับ
# 212  452  ห้องใหญ่มากค่ะบริการดีเสียดายจองผ่านแอพมาน่าจะ...
# 214  454                                      ผ้าเช็ดตัวขาด
# 222  462                                              ไม่มี
# 225  465  อยากให้ปรับปรุงมากๆ ด้วยราคานี้ค่อนข้างน่าผิดหวัง
# 228  468                                   ห้องกว้างเริ่ดดด
# 229  469                         อาหารอร่อย พนักงานบริการดี
# 230  470                           พี่พนักงานดูแลดีมากๆค่ะ
# 237  477                                           โอเคแล้ว
# 240  480                      ควรแจ้งการเปลี่ยนให้ดีกว่านี้
# 255  495                                      อาหารอร่อยค่ะ
# 258  498                                        บริการดีค่ะ
# 298  538                   อาหารอร่อย บรรยากาศในห้องอาหารดี
# 301  541              ห้องพักติดถนน เสียงดังไป เเต่โดยรวมดี
# 307  547                                           บริการดี
# 313  553                                            房间相当潮湿。
# 321  561                   ห้องค่อนข้างเสียงดังนิดหน่อยครับ
# 325  565                          อาหารอร่อย การบริการดีค่ะ
# 349  589                                          ไม่มีครับ
# 352  592  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...
# 353  593                                           บริการดี
#
#                                             translated  \
# 1    We're back here on the fourth stop, sir. The r...
# 2                                        Good service.
# 4                Good journey, big road, good service.
# 5             There's a nice, clean smell in the room.
# 6                  Nice reception. Welcome drink cold.
# 15                    It's a bad smell in the hallway.
# 21   The employees gave good advice, the soft beds,...
# 26                                  The room is clean.
# 28   They should provide room-slipper shoes, room-t...
# 31                You're doing a really good job, Nan.
# 62                                               Good.
# 63   Good service, big smile, back to service, of c...
# 67                               It's okay. It's okay.
# 77                                       Room's clean.
# 78   Good staff, the room's wide, but unfortunately...
# 82                      It's a big room. Good service.
# 83                      The hotel's clear on the road.
# 85   (At 5pm, 8300 in the morning, the resort was g...
# 88   It's called Macro, a very good employee, a lar...
# 90   I'm here at the conference and I'm here at the...
# 92   The counter managers are very good, and they'r...
# 95                                            Nothing.
# 96                                                405.
# 97   The rooms are clean, my brothers and sisters a...
# 102  I haven't had a service in the conference room...
# 135     A nice, clean hotel. Smells great in the room.
# 137                                              Good.
# 144                            The room is very clean.
# 156  The E.R. Room's down. There's a power wave, bu...
# 160                        The room is very wide, sir.
# 162                                              Good.
# 166  It's very close to the colony, and it's easy t...
# 174                                 You're free to go.
# 176  Good stewards, clean rooms, nice maids, left s...
# 179                                         Good food.
# 186  The lights went out in the room, but the staff...
# 193                                         Nice room.
# 199                                    It's delicious.
# 204                                      Room's clean.
# 212  It's a big room. It's a nice service. I could ...
# 214                                The towel's broken.
# 222                                           Nothing.
# 225  I'd like to make a lot of improvements at this...
# 228                                   It's a big room.
# 229                             Good food, good staff.
# 230                       The staff's doing very well.
# 237                                        Okay, then.
# 240                A better change should be reported.
# 255                                    It's delicious.
# 258                                      Good service.
# 298  The food is good. The atmosphere is good in th...
# 301         Roadrooms are too loud, but it's all good.
# 307                                      Good service.
# 313                                          . . . . .
# 321                         The room's a little noisy.
# 325                           Good food. Good service.
# 349                                           No, sir.
# 352     The room is very nice. It's clean. Good staff.
# 353                                      Good service.
#
#                                          sentiment_set  Positive_Score  \
# 1    [{'label': 'POSITIVE', 'score': 0.999060213565...        0.999060
# 2    [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
# 4    [{'label': 'POSITIVE', 'score': 0.999871969223...        0.999872
# 5    [{'label': 'POSITIVE', 'score': 0.999780356884...        0.999780
# 6    [{'label': 'POSITIVE', 'score': 0.999289512634...        0.999290
# 15   [{'label': 'NEGATIVE', 'score': 0.999786913394...        0.000213
# 21   [{'label': 'POSITIVE', 'score': 0.997725903987...        0.997726
# 26   [{'label': 'POSITIVE', 'score': 0.999398589134...        0.999399
# 28   [{'label': 'NEGATIVE', 'score': 0.995548367500...        0.004452
# 31   [{'label': 'POSITIVE', 'score': 0.999854445457...        0.999854
# 62   [{'label': 'POSITIVE', 'score': 0.999815762042...        0.999816
# 63   [{'label': 'POSITIVE', 'score': 0.999829411506...        0.999829
# 67   [{'label': 'POSITIVE', 'score': 0.999826848506...        0.999827
# 77   [{'label': 'POSITIVE', 'score': 0.999276340007...        0.999276
# 78   [{'label': 'POSITIVE', 'score': 0.999377429485...        0.999377
# 82   [{'label': 'POSITIVE', 'score': 0.999843835830...        0.999844
# 83   [{'label': 'POSITIVE', 'score': 0.999705970287...        0.999706
# 85   [{'label': 'POSITIVE', 'score': 0.970934271812...        0.970934
# 88   [{'label': 'POSITIVE', 'score': 0.999601900577...        0.999602
# 90   [{'label': 'POSITIVE', 'score': 0.998492598533...        0.998493
# 92   [{'label': 'POSITIVE', 'score': 0.999853491783...        0.999853
# 95   [{'label': 'NEGATIVE', 'score': 0.999634861946...        0.000365
# 96   [{'label': 'NEGATIVE', 'score': 0.913557052612...        0.086443
# 97   [{'label': 'NEGATIVE', 'score': 0.977753758430...        0.022246
# 102  [{'label': 'POSITIVE', 'score': 0.999591886997...        0.999592
# 135  [{'label': 'POSITIVE', 'score': 0.999877572059...        0.999878
# 137  [{'label': 'POSITIVE', 'score': 0.999815762042...        0.999816
# 144  [{'label': 'POSITIVE', 'score': 0.999219536781...        0.999220
# 156  [{'label': 'NEGATIVE', 'score': 0.996005594730...        0.003994
# 160  [{'label': 'POSITIVE', 'score': 0.999501347541...        0.999501
# 162  [{'label': 'POSITIVE', 'score': 0.999815762042...        0.999816
# 166  [{'label': 'NEGATIVE', 'score': 0.998827278614...        0.001173
# 174  [{'label': 'POSITIVE', 'score': 0.999678850173...        0.999679
# 176  [{'label': 'NEGATIVE', 'score': 0.980466306209...        0.019534
# 179  [{'label': 'POSITIVE', 'score': 0.999863982200...        0.999864
# 186  [{'label': 'NEGATIVE', 'score': 0.994319558143...        0.005680
# 193  [{'label': 'POSITIVE', 'score': 0.999868035316...        0.999868
# 199  [{'label': 'POSITIVE', 'score': 0.999880790710...        0.999881
# 204  [{'label': 'POSITIVE', 'score': 0.999276340007...        0.999276
# 212  [{'label': 'POSITIVE', 'score': 0.999519109725...        0.999519
# 214  [{'label': 'NEGATIVE', 'score': 0.999607741832...        0.000392
# 222  [{'label': 'NEGATIVE', 'score': 0.999634861946...        0.000365
# 225  [{'label': 'NEGATIVE', 'score': 0.999548614025...        0.000451
# 228  [{'label': 'POSITIVE', 'score': 0.999630451202...        0.999630
# 229  [{'label': 'POSITIVE', 'score': 0.999863028526...        0.999863
# 230  [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
# 237  [{'label': 'POSITIVE', 'score': 0.998957991600...        0.998958
# 240  [{'label': 'NEGATIVE', 'score': 0.944746792316...        0.055253
# 255  [{'label': 'POSITIVE', 'score': 0.999880790710...        0.999881
# 258  [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
# 298  [{'label': 'POSITIVE', 'score': 0.999868392944...        0.999868
# 301  [{'label': 'POSITIVE', 'score': 0.999775230884...        0.999775
# 307  [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
# 313  [{'label': 'POSITIVE', 'score': 0.878417134284...        0.878417
# 321  [{'label': 'NEGATIVE', 'score': 0.999675750732...        0.000324
# 325  [{'label': 'POSITIVE', 'score': 0.999864935874...        0.999865
# 349  [{'label': 'NEGATIVE', 'score': 0.999142646789...        0.000857
# 352  [{'label': 'POSITIVE', 'score': 0.999870300292...        0.999870
# 353  [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
#
#      Negative_Score
# 1          0.000940
# 2          0.000147
# 4          0.000128
# 5          0.000220
# 6          0.000710
# 15         0.999787
# 21         0.002274
# 26         0.000601
# 28         0.995548
# 31         0.000146
# 62         0.000184
# 63         0.000171
# 67         0.000173
# 77         0.000724
# 78         0.000623
# 82         0.000156
# 83         0.000294
# 85         0.029066
# 88         0.000398
# 90         0.001507
# 92         0.000147
# 95         0.999635
# 96         0.913557
# 97         0.977754
# 102        0.000408
# 135        0.000122
# 137        0.000184
# 144        0.000780
# 156        0.996006
# 160        0.000499
# 162        0.000184
# 166        0.998827
# 174        0.000321
# 176        0.980466
# 179        0.000136
# 186        0.994320
# 193        0.000132
# 199        0.000119
# 204        0.000724
# 212        0.000481
# 214        0.999608
# 222        0.999635
# 225        0.999549
# 228        0.000370
# 229        0.000137
# 230        0.000147
# 237        0.001042
# 240        0.944747
# 255        0.000119
# 258        0.000147
# 298        0.000132
# 301        0.000225
# 307        0.000147
# 313        0.121583
# 321        0.999676
# 325        0.000135
# 349        0.999143
# 352        0.000130
# 353        0.000147

# %%
df = df[['ID','Date','Gender','Age_Range','Mean_Point']]
# df

# %%
# merge back

merged_df = pd.merge(df, filtered_df, on='ID', how='left')
merged_df.head()
# Out:
#     ID                Date  Gender Age_Range  Mean_Point  \
# 0  240 2023-08-03 07:34:18     ชาย     45-64    0.933333
# 1  241 2023-08-07 07:24:47  LGBTQ+     18-24    1.000000
# 2  242 2023-08-07 07:25:43     ชาย     25-34    1.000000
# 3  243 2023-08-07 07:26:29     ชาย     35-44    1.000000
# 4  244 2023-08-07 07:27:28    หญิง     25-34    1.000000
#
#                                           Comment  \
# 0                                             NaN
# 1   กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก
# 2                                 การบริการดีครับ
# 3                                             NaN
# 4         เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี
#
#                                           translated  \
# 0                                                NaN
# 1  We're back here on the fourth stop, sir. The r...
# 2                                      Good service.
# 3                                                NaN
# 4              Good journey, big road, good service.
#
#                                        sentiment_set  Positive_Score  \
# 0                                                NaN             NaN
# 1  [{'label': 'POSITIVE', 'score': 0.999060213565...        0.999060
# 2  [{'label': 'POSITIVE', 'score': 0.999853372573...        0.999853
# 3                                                NaN             NaN
# 4  [{'label': 'POSITIVE', 'score': 0.999871969223...        0.999872
#
#    Negative_Score
# 0             NaN
# 1        0.000940
# 2        0.000147
# 3             NaN
# 4        0.000128

# %%
merged_df = merged_df.drop(columns=['translated','sentiment_set'])
merged_df
# Out:
#       ID                Date  Gender Age_Range  Mean_Point  \
# 0    240 2023-08-03 07:34:18     ชาย     45-64    0.933333
# 1    241 2023-08-07 07:24:47  LGBTQ+     18-24    1.000000
# 2    242 2023-08-07 07:25:43     ชาย     25-34    1.000000
# 3    243 2023-08-07 07:26:29     ชาย     35-44    1.000000
# 4    244 2023-08-07 07:27:28    หญิง     25-34    1.000000
# ..   ...                 ...     ...       ...         ...
# 349  589 2024-05-02 12:44:34     ชาย     35-44    0.917568
# 350  590 2024-05-02 13:09:21     ชาย     45-64    0.833333
# 351  591 2024-05-02 13:09:17     ชาย     45-64    0.894414
# 352  592 2024-05-03 09:13:21     ชาย     18-24    1.000000
# 353  593 2024-05-04 20:10:13    หญิง     25-34    1.000000
#
#                                                Comment  Positive_Score  \
# 0                                                  NaN             NaN
# 1        กลับมาพักที่นี่รอบที่4 เเล้วค่ะ ห้องกว้างมาก         0.999060
# 2                                      การบริการดีครับ        0.999853
# 3                                                  NaN             NaN
# 4              เดินทางสะดวกสบาย ติดถนนใหญ่ การบริการดี        0.999872
# ..                                                 ...             ...
# 349                                          ไม่มีครับ        0.000857
# 350                                                NaN             NaN
# 351                                                NaN             NaN
# 352  ห้องพักดีมากครับ สะอาดเรียบร้อย พนักงานบริการด...        0.999870
# 353                                           บริการดี        0.999853
#
#      Negative_Score
# 0               NaN
# 1          0.000940
# 2          0.000147
# 3               NaN
# 4          0.000128
# ..              ...
# 349        0.999143
# 350             NaN
# 351             NaN
# 352        0.000130
# 353        0.000147
#
# [354 rows x 8 columns]

# %%
# Export clean file (overwrite)
merged_df.to_csv('clean_data.csv', index=False)
